# %% [markdown]
# All data downloaded from https://www.skysports.com/

# %%
import pandas as pd

# %%
links_df = pd.read_csv("./initial_ds/match_stat_links.csv")

# %%
try:
    stats_df = pd.read_csv("./initial_ds/match_stats.csv")
except:
    stats_df = pd.DataFrame(columns=[
        'stats_link',
        'match_date',
        'venue',
        'attendance',
        'home_possession',
        'away_possession',
        'home_total_shots',
        'away_total_shots',
        'home_shots_on_target',
        'away_shots_on_target',
        'home_shots_off_target',
        'away_shots_off_target',
        'home_blocked',
        'away_blocked',
        'home_passing_percent',
        'away_passing_percent',
        'home_clear_cut_chances',
        'away_clear_cut_chances',
        'home_corners',
        'away_corners',
        'home_offsides',
        'away_offsides',
        'home_tackles_percent',
        'away_tackles_percent',
        'home_aerial_duels',
        'away_aerial_duels',
        'home_saves',
        'away_saves',
        'home_fouls_committed',
        'away_fouls_committed',
        'home_fouls_won',
        'away_fouls_won',
        'home_yellow_cards',
        'away_yellow_cards',
        'home_red_cards',
        'away_red_cards',
    ])
    
print(f"Currently holding {stats_df.shape[0]} instances.")
# Out:
# Currently holding 2069 instances.

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import re

# Getting the list of links to scrape
stats_links = links_df[~links_df['stats_link'].isin(stats_df['stats_link'])]['stats_link']

try:
    # Initiating a new Google Chrome window
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
    
    # Going through the list of links and scraping them one by one
    for stats_link in stats_links:
        print(f"Adding the link:\n{stats_link}\n")
        # Retrieving the URL in the Chrome window
        driver.get(stats_link)
        stats = BeautifulSoup(driver.page_source, 'lxml')
            
        # Extracting the date
        match_date = stats.find('time').text
            
        # Extracting the match's venue
        venue_element = stats.find('span', attrs={"class": 'sdc-site-match-header__detail-venue'})
        venue = venue_element and venue_element.text
        
        # Extracting the venue's attendance
        attendance_element = stats.find('span', attrs={"class": 'sdc-site-match-header__detail-attendance-label'})
        attendance_label = attendance_element and attendance_element.next_sibling
        attendance = attendance_label and ''.join(re.findall('\d', attendance_label.get_text()))
        
        # Extracting all other stats
        other_stats = [s.text for s in stats.find_all('span', attrs={'class': 'sdc-site-match-stats__stats-label'})]
        other_stats.extend([None for i in range(32 - len(other_stats))])
        
        # Combining all the single stats into a list
        values = [
            stats_link,
            match_date,
            venue,
            attendance,
        ] + other_stats
        
        # Saving the list of stats into the dataframe
        print(f"The extracted values:\n{values}\n(Total of {len(values)})\n")
        stats_df.loc[len(stats_df)] = values
except Exception as e:
    print(f"Error occurred while scraping the link:\n{stats_link}\n")
    raise e      
finally:
    # Saving the newly added stats into file
    stats_df.to_csv("./initial_ds/match_stats.csv", index=False)
# Out:
# Adding the link:
# https://www.skysports.com/football/real-betis-vs-girona/stats/469571
#
# The extracted values:
# ['https://www.skysports.com/football/real-betis-vs-girona/stats/469571', '5:30pm, Sunday 18th September 2022.', 'Benito Villamarin', '52229', '44', '56', '9', '9', '3', '3', '3', '5', '3', '1', '84.8', '87.2', '0', '2', '2', '4', '2', '5', '42.1', '40.9', '50', '50', '2', '1', '9', '8', '8', '9', '0', '3', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/real-sociedad-vs-espanyol/stats/469572
#
# The extracted values:
# ['https://www.skysports.com/football/real-sociedad-vs-espanyol/stats/469572', '5:30pm, Sunday 18th September 2022.', 'Reale Seguros Stadium', '31511', '62.9', '37.1', '14', '14', '6', '4', '5', '7', '3', '3', '81.2', '67.7', '4', '1', '4', '2', '2', '3', '64.3', '55.6', '49', '51', '3', '4', '18', '8', '8', '17', '3', '0', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/atletico-madrid-vs-real-madrid/stats/469567
#
# The extracted values:
# ['https://www.skysports.com/football/atletico-madrid-vs
# The extracted values:
# ['https://www.skysports.com/football/getafe-vs-real-sociedad/stats/469561', '5:30pm, Sunday 11th September 2022.', 'Coliseum Alfonso Perez', '11112', '32.9', '67.1', '8', '13', '3', '6', '3', '5', '2', '2', '68.4', '84.5', '0', '3', '3', '7', '1', '0', '66.7', '44.4', '46.2', '53.8', '5', '1', '9', '16', '15', '9', '4', '1', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/real-betis-vs-villarreal/stats/469564
#
# The extracted values:
# ['https://www.skysports.com/football/real-betis-vs-villarreal/stats/469564', '8:00pm, Sunday 11th September 2022.', 'Benito Villamarin', '53276', '47.4', '52.6', '16', '14', '5', '3', '6', '4', '5', '7', '85.6', '86.4', '2', '5', '9', '8', '4', '6', '75', '76.5', '43.5', '56.5', '2', '4', '11', '14', '13', '11', '1', '1', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/rayo-vallecano-vs-valencia/stats/469563
#
# The extracted values:
# ['https://www.skysports.com/football/rayo-vallecano-vs-valencia/stats/469563', '1:00pm, Saturday 10th September 2022.', 'Campo de Futbol de Vallecas', '12085', '45.7', '54.3', '14', '17', '6', '4', '5', '6', '3', '7', '71.3', '77.1', '3', '3', '7', '7', '1', '2', '50', '41.2', '32.1', '67.9', '3', '5', '22', '11', '9', '21', '5', '2', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/espanyol-vs-sevilla/stats/469560
#
# The extracted values:
# ['https://www.skysports.com/football/espanyol-vs-sevilla/stats/469560', '3:15pm, Saturday 10th September 2022.', 'Cornella - El Prat', '20135', '59.2', '40.8', '19', '11', '5', '7', '9', '1', '5', '3', '81.8', '74.5', '1', '2', '9', '3', '3', '1', '72.7', '66.7', '68', '32', '4', '3', '11', '14', '13', '11', '3', '3', '0', '1']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/cadiz-vs-barcelona/stats/469558
#
# The extracted values:
# ['https://www.skysports.com/football/cadiz-vs-barcelona/stats/469558', '5:30pm, Saturday 10th September 2022.', 'Ramon de Carranza', '19530', '29.5', '70.5', '6', '16', '0', '8', '6', '6', '0', '2', '64.8', '84.9', '0', '1', '5', '6', '3', '3', '70.6', '33.3', '43.3', '56.7', '4', '0', '12', '13', '13', '11', '1', '3', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/atletico-madrid-vs-celta-vigo/stats/469557
#
# The extracted values:
# ['https://www.skysports.com/football/atletico-madrid-vs-celta-vigo/stats/469557', '8:00pm, Saturday 10th September 2022.', 'Wanda Metropolitano', '52247', '45.7', '54.3', '10', '14', '4', '3', '2', '5', '4', '6', '82.8', '87.1', '1', '2', '4', '7', '0', '1', '66.7', '61.5', '54.5', '45.5', '2', '1', '11', '6', '6', '10', '2', '3', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/girona-vs-real-valladolid/stats/469562
#
# The extracted values:
# ['https://www.skysports.com/football/girona-vs-real-valladolid/stats/469562', '8:00pm, Friday 9th September 2022.', 'Municipal de Montilivi', '10053', '44.7', '55.3', '14', '14', '5', '4', '8', '3', '1', '7', '77.4', '84', '4', '0', '3', '12', '3', '0', '52.2', '68.8', '54.8', '45.2', '3', '3', '11', '15', '14', '11', '0', '2', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/real-valladolid-vs-almeria/stats/469552
#
# The extracted values:
# ['https://www.skysports.com/football/real-valladolid-vs-almeria/stats/469552', '8:00pm, Monday 5th September 2022.', 'Jose Zorrilla', '20260', '52', '48', '14', '12', '6', '1', '7', '3', '1', '8', '78.1', '74.8', '3', '0', '2', '8', '6', '4', '40', '41.7', '40', '60', '0', '5', '11', '19', '17', '11', '1', '6', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/osasuna-vs-rayo-vallecano/stats/469549
#
# The extracted values:
# ['https://www.skysports.com/football/osasuna-vs-rayo-vallecano/stats/469549', '1:00pm, Sunday 4th September 2022.', 'El Sadar', '18745', '46.4', '53.6', '13', '5', '6', '3', '4', '1', '3', '1', '70.8', '77.6', '4', '0', '4', '0', '3', '2', '62.5', '78.6', '51.5', '48.5', '2', '3', '14', '16', '16', '13', '2', '2', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/athletic-bilbao-vs-espanyol/stats/469546
#
# The extracted values:
# ['https://www.skysports.com/football/athletic-bilbao-vs-espanyol/stats/469546', '3:15pm, Sunday 4th September 2022.', 'San Mames', '41574', '66.5', '33.5', '17', '9', '2', '2', '11', '4', '4', '3', '83.7', '66.7', '1', '2', '4', '2', '3', '2', '42.9', '68.8', '42.4', '57.6', '1', '3', '12', '12', '12', '12', '3', '2', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/villarreal-vs
'0', '1']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/girona-vs-getafe/stats/469531
#
# The extracted values:
# ['https://www.skysports.com/football/girona-vs-getafe/stats/469531', '9:00pm, Monday 22nd August 2022.', 'Municipal de Montilivi', '10460', '67.3', '32.7', '12', '7', '6', '3', '5', '4', '1', '0', '88', '75.7', '2', '1', '5', '2', '2', '1', '61.5', '50', '32', '68', '2', '4', '16', '18', '18', '16', '2', '6', '0', '1']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/athletic-bilbao-vs-valencia/stats/469526
#
# The extracted values:
# ['https://www.skysports.com/football/athletic-bilbao-vs-valencia/stats/469526', '4:30pm, Sunday 21st August 2022.', 'San Mames', '43333', '37.2', '62.8', '12', '10', '2', '0', '6', '6', '4', '4', '74.8', '84.5', '1', '1', '6', '3', '6', '0', '70.6', '66.7', '66.7', '33.3', '0', '1', '11', '15', '14', '10', '5', '2', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/atletico-madrid-vs-villarreal/stats/469527
#
# The extracted values:
# ['https://www.skysports.com/football/atletico-madrid-vs-villarreal/stats/469527', '6:30pm, Sunday 21st August 2022.', 'Wanda Metropolitano', '57033', '50.2', '49.8', '13', '19', '5', '5', '6', '5', '2', '9', '86.7', '90.2', '2', '3', '5', '6', '2', '1', '83.3', '33.3', '54.2', '45.8', '3', '5', '8', '11', '10', '8', '2', '2', '1', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/real-sociedad-vs-barcelona/stats/469534
#
# The extracted values:
# ['https://www.skysports.com/football/real-sociedad-vs-barcelona/stats/469534', '9:00pm, Sunday 21st August 2022.', 'Reale Seguros Stadium', '36201', '41.3', '58.7', '10', '15', '5', '7', '3', '3', '2', '5', '81.8', '90.2', '0', '2', '4', '6', '5', '1', '52', '55', '53.3', '46.7', '3', '4', '15', '9', '9', '15', '2', '1', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/osasuna-vs-cadiz/stats/469533
#
# The extracted values:
# ['https://www.skysports.com/football/osasuna-vs-cadiz/stats/469533', '4:30pm, Saturday 20th August 2022.', 'El Sadar', '18587', '55.6', '44.4', '16', '9', '3', '2', '8', '3', '5', '4', '75.8', '73.4', '2', '0', '2', '2', '0', '1', '53.8', '46.7', '62.8', '37.2', '2', '2', '11', '13', '13', '9', '2', '3', '0', '1']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/real-mallorca-vs-real-betis/stats/469532
#
# The extracted values:
# ['https://www.skysports.com/football/real-mallorca-vs-real-betis/stats/469532', '6:30pm, Saturday 20th August 2022.', 'Iberostar Estadi', '15579', '47.1', '52.9', '13', '8', '7', '3', '3', '4', '3', '1', '79.1', '81.6', '3', '1', '5', '2', '4', '0', '64.7', '70', '60.7', '39.3', '1', '6', '22', '17', '15', '20', '7', '8', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/celta-vigo-vs-real-madrid/stats/469528
#
# The extracted values:
# ['https://www.skysports.com/football/celta-vigo-vs-real-madrid/stats/469528', '9:00pm, Saturday 20th August 2022.', 'Balaidos', '15681', '50.8', '49.2', '15', '16', '2', '7', '8', '5', '5', '4', '88.2', '88.3', '0', '3', '2', '2', '0', '1', '69.2', '57.1', '61.5', '38.5', '3', '1', '12', '8', '6', '10', '2', '2', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/espanyol-vs-rayo-vallecano/stats/469530
#
# The extracted values:
# ['https://www.skysports.com/football/espanyol-vs-rayo-vallecano/stats/469530', '7:00pm, Friday 19th August 2022.', 'Cornella - El Prat', '16071', '54.4', '45.6', '13', '8', '1', '3', '8', '4', '4', '1', '85.8', '81.3', '2', '3', '9', '2', '3', '2', '54.5', '100', '70.4', '29.6', '1', '1', '12', '17', '15', '11', '2', '3', '1', '1']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/sevilla-vs-real-valladolid/stats/469535
#
# The extracted values:
# ['https://www.skysports.com/football/sevilla-vs-real-valladolid/stats/469535', '9:00pm, Friday 19th August 2022.', 'Ramon Sanchez Pizjuan', '33991', '61.4', '38.6', '18', '6', '2', '3', '11', '2', '5', '1', '85', '74.3', '2', '1', '12', '2', '4', '4', '61.1', '80', '50', '50', '2', '1', '20', '10', '10', '19', '3', '2', '1', '1']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/athletic-bilbao-vs-real-mallorca/stats/469517
#
# The extracted values:
# ['https://www.skysports.com/football/athletic-bilbao-vs-real-mallorca/stats/469517', '4:30pm, Monday 15th August 2022.', 'San Mames', '39747', '64.2', '35.8', '23', '6', '6', '2', '10', '2', '7', '2', '82.4', '67.3', '1', '0', '7', '2', '1', '0', '50', '47.4', '57.1', '42.9', '2', '6', '13', '12', '12', '13', '0', '6', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/getafe-vs-atletico-madrid/stats/469521
#
# The extracted values:
# ['https://www.skysports.com/football/getafe-vs-atletico-madrid/stats/469521', '6:30pm, Monday 15th August 2022.', 'Coliseum Alfonso Perez', '12235', '42', '58', '10', '12', '0', '5', '9', '2', '1', '5', '79.2', '86.4', '2', '2', '3', '6', '0', '5', '54.5', '75', '56', '44', '2', '0', '14', '19', '19', '12', '2', '1', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/real-betis-vs-elche/stats/469523
#
# The extracted values:
# ['https://www.skysports.com/football/real-betis-vs-elche/stats/469523', '8:30pm, Monday 15th August 2022.', 'Benito Villamarin', '50622', '72.4', '27.6', '17', '4', '8', '2', '5', '1', '4', '1', '89.1', '69.2', '3', '0', '8', '4', '5', '3', '68.8', '66.7', '70', '30', '1', '5', '10', '18', '18', '10', '3', '6', '0', '1']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/cadiz-vs-real-sociedad/stats/469520
#
# The extracted values:
# ['https://www.skysports.com/football/cadiz-vs-real-sociedad/stats/469520', '4:30pm, Sunday 14th August 2022.', 'Ramon de Carranza', '16570', '39.7', '60.3', '7', '15', '2', '7', '3', '3', '2', '5', '74.2', '80.9', '0', '3', '3', '6', '4', '0', '65', '60', '48.7', '51.3', '6', '1', '9', '20', '19', '9', '4', '2', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/valencia-vs-girona/stats/469525
#
# The extracted values:
# ['https://www.skysports.com/football/valencia-vs-girona/stats/469525', '6:30pm, Sunday 14th August 2022.', 'Mestalla', '39359', '46.1', '53.9', '17', '5', '2', '1', '7', '2', '8', '2', '81', '83.4', '0', '0', '4', '4', '1', '2', '85.7', '30.8', '39.1', '60.9', '1', '2', '18', '14', '13', '18', '2', '3', '1', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/almeria-vs-real-madrid/stats/469516
#
# The extracted values:
# ['https://www.skysports.com/football/almeria-vs-real-madrid/stats/469516', '9:00pm, Sunday 14th August 2022.', 'Juegos del Mediterraneo', '14386', '32.4', '67.6', '10', '29', '6', '15', '3', '4', '1', '10', '81.6', '91.4', '1', '4', '2', '15', '3', '3', '63.6', '44.4', '58.3', '41.7', '13', '5', '11', '4', '4', '11', '3', '1', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/celta-vigo-vs-espanyol/stats/469519
#
# The extracted values:
# ['https://www.skysports.com/football/celta-vigo-vs-espanyol/stats/469519', '4:00pm, Saturday 13th August 2022.', 'Balaidos', '13859', '59.9', '40.1', '8', '10', '3', '2', '3', '5', '2', '3', '82.2', '76.4', '0', '0', '3', '3', '1', '0', '42.1', '55.6', '48', '52', '0', '1', '17', '15', '15', '17', '5', '2', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/real-valladolid-vs-villarreal/stats/469524
#
# The extracted values:
# ['https://www.skysports.com/football/real-valladolid-vs-villarreal/stats/469524', '6:00pm, Saturday 13th August 2022.', 'Jose Zorrilla', '17543', '51.8', '48.2', '12', '10', '6', '4', '5', '4', '1', '2', '83.4', '78', '1', '1', '4', '5', '2', '1', '50', '55.6', '45.5', '54.5', '1', '6', '6', '10', '10', '5', '1', '0', '0', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/barcelona-vs-rayo-vallecano/stats/469518
#
# The extracted values:
# ['https://www.skysports.com/football/barcelona-vs-rayo-vallecano/stats/469518', '8:00pm, Saturday 13th August 2022.', 'Spotify Camp Nou', '81104', '67.5', '32.5', '21', '4', '6', '2', '9', '2', '6', '0', '87.3', '69.7', '1', '1', '8', '0', '4', '4', '62.5', '83.3', '64.7', '35.3', '2', '5', '16', '14', '14', '16', '1', '6', '1', '0']
# (Total of 36)
#
# Adding the link:
# https://www.skysports.com/football/osasuna-vs-sevilla/stats/469522
#
# The extracted values:
# ['https://www.skysports.com/football/osasuna-vs-sevilla/stats/469522', '8:00pm, Friday 12th August 2022.', 'El Sadar', '18536', '34.4', '65.6', '12', '10', '5', '3', '3', '4', '4', '3', '78.8', '86.9', '1', '1', '5', '2', '5', '2', '63.6', '66.7', '30.8', '69.2', '2', '3', '16', '9', '9', '16', '5', '3', '0', '0']
# (Total of 36)
