# %% [markdown]
# All data downloaded from https://www.skysports.com/

# %%
import pandas as pd

# %%
links_df = pd.read_csv("./initial_ds/match_stat_links.csv")

# %%
try:
    stats_df = pd.read_csv("./initial_ds/match_stats.csv")
except:
    stats_df = pd.DataFrame(columns=[
        'stats_link',
        'match_date',
        'venue',
        'attendance',
        'home_possession',
        'away_possession',
        'home_total_shots',
        'away_total_shots',
        'home_shots_on_target',
        'away_shots_on_target',
        'home_shots_off_target',
        'away_shots_off_target',
        'home_blocked',
        'away_blocked',
        'home_passing_percent',
        'away_passing_percent',
        'home_clear_cut_chances',
        'away_clear_cut_chances',
        'home_corners',
        'away_corners',
        'home_offsides',
        'away_offsides',
        'home_tackles_percent',
        'away_tackles_percent',
        'home_aerial_duels',
        'away_aerial_duels',
        'home_saves',
        'away_saves',
        'home_fouls_committed',
        'away_fouls_committed',
        'home_fouls_won',
        'away_fouls_won',
        'home_yellow_cards',
        'away_yellow_cards',
        'home_red_cards',
        'away_red_cards',
    ])
    
print(f"Currently holding {stats_df.shape[0]} instances.")
# Out:
# Currently holding 1706 instances.

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import re

# Getting the list of links to scrape
stats_links = links_df[~links_df['stats_link'].isin(stats_df['stats_link'])]['stats_link']
remaining_links = total_links = stats_links.shape[0]

try:
    # Initiating a new Google Chrome window
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
    
    # Going through the list of links and scraping them one by one
    for stats_link in stats_links:
        print(f"Adding the link:\n{stats_link}\n...")
        # Retrieving the URL in the Chrome window
        driver.get(stats_link)
        stats = BeautifulSoup(driver.page_source, 'lxml')
            
        # Extracting the date
        match_date = stats.find('time').text
            
        # Extracting the match's venue
        venue_element = stats.find('span', attrs={"class": 'sdc-site-match-header__detail-venue'})
        venue = venue_element and venue_element.text
        
        # Extracting the venue's attendance
        attendance_element = stats.find('span', attrs={"class": 'sdc-site-match-header__detail-attendance-label'})
        attendance_label = attendance_element and attendance_element.next_sibling
        attendance = attendance_label and ''.join(re.findall('\d', attendance_label.get_text()))
        
        # Extracting all other stats
        other_stats = [s.text for s in stats.find_all('span', attrs={'class': 'sdc-site-match-stats__stats-label'})]
        other_stats.extend([None for i in range(32 - len(other_stats))])
        
        # Combining all the single stats into a list
        values = [
            stats_link,
            match_date,
            venue,
            attendance,
        ] + other_stats
        
        # Saving the list of stats into the dataframe
        print(f"The extracted values:\n{values}\n(Total of {len(values)})\n")
        stats_df.loc[len(stats_df)] = values
        remaining_links -= 1
        print(f"Total of {total_links - remaining_links} links scraped, {remaining_links} links remaining.\n")
except Exception as e:
    print(f"Error occurred while scraping the link:\n{stats_link}\n")
    raise e      
finally:
    # Saving the newly added stats into file
    stats_df.to_csv("./initial_ds/match_stats.csv", index=False)
# Out:
# Adding the link:
# https://www.skysports.com/football/cadiz-vs-sevilla/stats/450681
# ...
# The extracted values:
# ['https://www.skysports.com/football/cadiz-vs-sevilla/stats/450681', '8:15pm, Monday 3rd January 2022.', 'Ramon de Carranza', '14342', '25.2', '74.8', '9', '14', '2', '4', '6', '9', '1', '1', '65', '90.8', '0', '2', '2', '8', '2', '4', '85.7', '57.1', '40.6', '59.4', '2', '2', '4', '9', '9', '4', '0', '1', '0', '0']
# (Total of 36)
#
# Total of 1 links scraped, 187 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/getafe-vs-real-madrid/stats/450683
# ...
# The extracted values:
# ['https://www.skysports.com/football/getafe-vs
links remaining.
#
# Adding the link:
# https://www.skysports.com/football/athletic-bilbao-vs-real-madrid/stats/450699
# ...
# The extracted values:
# ['https://www.skysports.com/football/athletic-bilbao-vs-real-madrid/stats/450699', '8:30pm, Wednesday 22nd December 2021.', 'San Mames', '42722', '40.2', '59.8', '15', '12', '2', '7', '6', '3', '7', '2', '87.4', '90.4', '1', '2', '7', '0', '2', '1', '22.2', '75', '41.7', '58.3', '5', '1', '17', '7', '7', '16', '2', '2', '0', '0']
# (Total of 36)
#
# Total of 10 links scraped, 178 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/villarreal-vs-alaves/stats/450538
# ...
# The extracted values:
# ['https://www.skysports.com/football/villarreal-vs-alaves/stats/450538', '6:00pm, Tuesday 21st December 2021.', 'Estadio de la Ceramica', '12530', '62.2', '37.8', '24', '4', '10', '2', '8', '2', '6', '0', '86.4', '79', '4', '0', '6', '2', '2', '7', '66.7', '66.7', '26.5', '73.5', '1', '5', '16', '14', '14', '15', '0', '2', '0', '0']
# (Total of 36)
#
# Total of 11 links scraped, 177 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/sevilla-vs-barcelona/stats/450537
# ...
# The extracted values:
# ['https://www.skysports.com/football/sevilla-vs-barcelona/stats/450537', '8:30pm, Tuesday 21st December 2021.', 'Ramon Sanchez Pizjuan', '31358', '41.4', '58.6', '5', '23', '1', '7', '3', '9', '1', '7', '78.5', '85.9', '0', '2', '4', '9', '2', '1', '57.1', '63.2', '42.9', '57.1', '6', '0', '15', '13', '13', '15', '2', '3', '1', '0']
# (Total of 36)
#
# Total of 12 links scraped, 176 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/levante-vs-valencia/stats/450674
# ...
# The extracted values:
# ['https://www.skysports.com/football/levante-vs-valencia/stats/450674', '8:00pm, Monday 20th December 2021.', 'Ciutat de Valencia', '18851', '51.6', '48.4', '15', '15', '9', '8', '3', '4', '3', '3', '75.1', '72.8', '2', '1', '6', '4', '5', '2', '50', '58.8', '70.8', '29.2', '4', '6', '21', '11', '9', '21', '2', '3', '1', '1']
# (Total of 36)
#
# Total of 13 links scraped, 175 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/granada-vs-real-mallorca/stats/450673
# ...
# The extracted values:
# ['https://www.skysports.com/football/granada-vs-real-mallorca/stats/450673', '1:00pm, Sunday 19th December 2021.', 'Estadio Los Carmenes', '13014', '45.6', '54.4', '15', '8', '6', '5', '5', '3', '4', '0', '67.9', '76.3', '2', '2', '4', '2', '1', '5', '64.7', '69.2', '39.4', '60.6', '4', '3', '12', '15', '14', '12', '3', '2', '0', '0']
# (Total of 36)
#
# Total of 14 links scraped, 174 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/athletic-bilbao-vs-real-betis/stats/450669
# ...
# The extracted values:
# ['https://www.skysports.com/football/athletic-bilbao-vs-real-betis/stats/450669', '3:15pm, Sunday 19th December 2021.', 'San Mames', '38002', '43.6', '56.4', '9', '16', '6', '8', '1', '3', '2', '5', '77.8', '81.4', '2', '2', '5', '6', '5', '1', '41.7', '60', '45.9', '54.1', '6', '3', '7', '12', '11', '6', '1', '3', '0', '0']
# (Total of 36)
#
# Total of 15 links scraped, 173 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/getafe-vs-osasuna/stats/450672
# ...
# The extracted values:
# ['https://www.skysports.com/football/getafe-vs-osasuna/stats/450672', '5:30pm, Sunday 19th December 2021.', 'Coliseum Alfonso Perez', '8126', '48.5', '51.5', '18', '11', '3', '3', '9', '5', '6', '3', '73.4', '72.9', '1', '1', '4', '3', '3', '4', '70', '81.8', '56.9', '43.1', '3', '2', '14', '8', '7', '13', '3', '1', '0', '0']
# (Total of 36)
#
# Total of 16 links scraped, 172 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-madrid-vs-cadiz/stats/450676
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-madrid-vs-cadiz/stats/450676', '8:00pm, Sunday 19th December 2021.', 'Santiago Bernabeu', '38818', '82.1', '17.9', '36', '4', '9', '0', '12', '4', '15', '0', '91.1', '53.7', '3', '0', '13', '2', '3', '1', '60', '52.6', '80.6', '19.4', '0', '9', '9', '10', '10', '9', '1', '1', '0', '0']
# (Total of 36)
#
# Total of 17 links scraped, 171 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/rayo-vallecano-vs
# The extracted values:
# ['https://www.skysports.com/football/rayo-vallecano-vs-espanyol/stats/450656', '1:00pm, Sunday 5th December 2021.', 'Campo de Futbol de Vallecas', '8679', '49.9', '50.1', '7', '10', '0', '3', '6', '3', '1', '4', '78.5', '79', '1', '0', '6', '3', '3', '0', '64.7', '70.6', '47.6', '52.4', '3', '0', '18', '11', '11', '16', '3', '3', '0', '1']
# (Total of 36)
#
# Total of 34 links scraped, 154 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/elche-vs-cadiz/stats/450652
# ...
# The extracted values:
# ['https://www.skysports.com/football/elche-vs-cadiz/stats/450652', '3:15pm, Sunday 5th December 2021.', 'Martinez Valero', '11879', '57.2', '42.8', '8', '15', '3', '6', '3', '6', '2', '3', '80.8', '75.5', '3', '1', '3', '3', '3', '0', '57.7', '60', '43.5', '56.5', '5', '0', '16', '15', '13', '16', '7', '3', '0', '0']
# (Total of 36)
#
# Total of 35 links scraped, 153 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/levante-vs-osasuna/stats/450655
# ...
# The extracted values:
# ['https://www.skysports.com/football/levante-vs-osasuna/stats/450655', '5:30pm, Sunday 5th December 2021.', 'Ciutat de Valencia', '15361', '57.8', '42.2', '11', '11', '3', '1', '5', '6', '3', '4', '77.8', '69.4', '0', '0', '7', '2', '1', '1', '45.5', '47.4', '53.5', '46.5', '1', '3', '12', '16', '15', '11', '2', '3', '0', '0']
# (Total of 36)
#
# Total of 36 links scraped, 152 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/celta-vigo-vs-valencia/stats/450651
# ...
# The extracted values:
# ['https://www.skysports.com/football/celta-vigo-vs-valencia/stats/450651', '8:00pm, Sunday 5th December 2021.', 'Balaidos', '11361', '66.9', '33.1', '11', '8', '5', '5', '3', '2', '3', '1', '77.6', '56.9', '2', '1', '6', '4', '0', '0', '47.4', '66.7', '50', '50', '3', '4', '10', '22', '21', '9', '3', '2', '0', '0']
# (Total of 36)
#
# Total of 37 links scraped, 151 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/sevilla-vs-villarreal/stats/450658
# ...
# The extracted values:
# ['https://www.skysports.com/football/sevilla-vs-villarreal/stats/450658', '1:00pm, Saturday 4th December 2021.', 'Ramon Sanchez Pizjuan', '30865', '45', '55', '8', '16', '3', '2', '2', '5', '3', '9', '76', '79.1', '1', '2', '5', '8', '2', '1', '61.5', '45', '64.3', '35.7', '2', '2', '9', '10', '10', '9', '2', '2', '0', '0']
# (Total of 36)
#
# Total of 38 links scraped, 150 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/barcelona-vs-real-betis/stats/450650
# ...
# The extracted values:
# ['https://www.skysports.com/football/barcelona-vs-real-betis/stats/450650', '3:15pm, Saturday 4th December 2021.', 'Camp Nou', '66529', '62.9', '37.1', '12', '8', '3', '2', '7', '4', '2', '2', '89.1', '76.8', '2', '1', '6', '1', '3', '3', '68.8', '62.1', '82.4', '17.6', '1', '3', '17', '12', '12', '16', '1', '2', '0', '0']
# (Total of 36)
#
# Total of 39 links scraped, 149 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/atletico-madrid-vs-real-mallorca/stats/450649
# ...
# The extracted values:
# ['https://www.skysports.com/football/atletico-madrid-vs-real-mallorca/stats/450649', '5:30pm, Saturday 4th December 2021.', 'Wanda Metropolitano', '51009', '58.4', '41.6', '14', '10', '6', '3', '6', '4', '2', '3', '84.9', '78.2', '2', '1', '8', '5', '1', '1', '39.3', '30', '48.8', '51.2', '1', '5', '13', '16', '16', '12', '2', '5', '0', '0']
# (Total of 36)
#
# Total of 40 links scraped, 148 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-sociedad-vs-real-madrid/stats/450657
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-sociedad-vs-real-madrid/stats/450657', '8:00pm, Saturday 4th December 2021.', 'Reale Seguros Stadium', '35765', '51.2', '48.8', '11', '13', '0', '8', '5', '3', '6', '2', '88.4', '85.6', '0', '4', '6', '5', '1', '1', '50', '68.4', '47.8', '52.2', '6', '0', '12', '8', '7', '11', '2', '0', '0', '0']
# (Total of 36)
#
# Total of 41 links scraped, 147 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/granada-vs-alaves/stats/450654
# ...
# The extracted values:
# ['https://www.skysports.com/football/granada-vs-alaves/stats/450654', '8:00pm, Friday 3rd December 2021.', 'Estadio Los Carmenes', '13511', '43.8', '56.2', '9', '14', '2', '2', '5', '10', '2', '2', '73.8', '79.9', '1', '1', '3', '5', '3', '2', '50', '61.5', '54.1', '45.9', '2', '0', '17', '15', '14', '15', '2', '2', '0', '0']
# (Total of 36)
#
# Total of 42 links scraped, 146 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-madrid-vs-athletic-bilbao/stats/450586
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-madrid-vs-athletic-bilbao/stats/450586', '8:00pm, Wednesday 1st December 2021.', 'Santiago Bernabeu', '33627', '62.1', '37.9', '17', '18', '7', '2', '5', '8', '5', '8', '89.8', '80.1', '2', '4', '7', '6', '3', '0', '44.4', '69.2', '36.4', '63.6', '2', '6', '12', '13', '11', '10', '2', '3', '0', '0']
# (Total of 36)
#
# Total of 43 links scraped, 145 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/osasuna-vs-elche/stats/450644
# ...
# The extracted values:
# ['https://www.skysports.com/football/osasuna-vs-elche/stats/450644', '8:00pm, Monday 29th November 2021.', 'El Sadar', '16485', '50.1', '49.9', '17', '10', '4', '4', '10', '4', '3', '2', '74.9', '73', '2', '3', '5', '4', '2', '0', '58.8', '40', '48.7', '51.3', '3', '3', '16', '12', '11', '16', '1', '3', '0', '0']
# (Total of 36)
#
# Total of 44 links scraped, 144 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-betis-vs-levante/stats/450645
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-betis-vs-levante/stats/450645', '1:00pm, Sunday 28th November 2021.', 'Benito Villamarin', '45012', '60.4', '39.6', '26', '8', '8', '2', '10', '2', '8', '4', '80.4', '66.4', '2', '1', '5', '8', '3', '8', '71.4', '55.6', '50', '50', '1', '5', '16', '9', '8', '13', '2', '3', '0', '0']
# (Total of 36)
#
# Total of 45 links scraped, 143 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/espanyol-vs-real-sociedad/stats/450642
# ...
# The extracted values:
# ['https://www.skysports.com/football/espanyol-vs-real-sociedad/stats/450642', '3:15pm, Sunday 28th November 2021.', 'Cornella - El Prat', '19935', '39.8', '60.2', '8', '10', '2', '4', '4', '3', '2', '3', '79.6', '87.2', '0', '0', '2', '9', '1', '2', '70.6', '58.3', '50', '50', '5', '1', '15', '7', '7', '13', '1', '1', '0', '0']
# (Total of 36)
#
# Total of 46 links scraped, 142 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/cadiz-vs-atletico-madrid/stats/450641
# ...
# The extracted values:
# ['https://www.skysports.com/football/cadiz-vs-atletico-madrid/stats/450641', '5:30pm, Sunday 28th November 2021.', 'Ramon de Carranza', '16861', '36.4', '63.6', '9', '17', '1', '7', '5', '5', '3', '5', '82.1', '87.5', '1', '4', '4', '8', '2', '2', '40', '35.7', '29.2', '70.8', '3', '0', '13', '11', '10', '13', '2', '0', '0', '0']
# (Total of 36)
#
# Total of 47 links scraped, 141 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-madrid-vs-sevilla/stats/450646
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-madrid-vs-sevilla/stats/450646', '8:00pm, Sunday 28th November 2021.', 'Santiago Bernabeu', '45281', '52.8', '47.2', '14', '11', '4', '6', '8', '3', '2', '2', '89.1', '89.4', '0', '2', '0', '4', '0', '1', '55.6', '80', '50', '50', '4', '2', '10', '9', '8', '10', '3', '3', '0', '0']
# (Total of 36)
#
# Total of 48 links scraped, 140 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/alaves-vs-celta-vigo/stats/450639
# ...
# The extracted values:
# ['https://www.skysports.com/football/alaves-vs-celta-vigo/stats/450639', '1:00pm, Saturday 27th November 2021.', 'Mendizorroza', '10093', '42.1', '57.9', '13', '8', '5', '5', '5', '2', '3', '1', '72.8', '79.8', '0', '1', '5', '3', '0', '2', '50', '66.7', '66.7', '33.3', '3', '4', '12', '15', '15', '11', '3', '2', '0', '0']
# (Total of 36)
#
# Total of 49 links scraped, 139 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/valencia-vs-rayo-vallecano/stats/450647
# ...
# The extracted values:
# ['https://www.skysports.com/football/valencia-vs-rayo-vallecano/stats/450647', '3:15pm, Saturday 27th November 2021.', 'Mestalla', '30030', '41.9', '58.1', '9', '12', '4', '6', '5', '5', '0', '1', '64.5', '72.4', '1', '1', '3', '9', '2', '3', '56.3', '64.3', '43.2', '56.8', '4', '3', '18', '16', '16', '18', '6', '5', '0', '0']
# (Total of 36)
#
# Total of 50 links scraped, 138 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-mallorca-vs-getafe/stats/450643
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-mallorca-vs-getafe/stats/450643', '5:30pm, Saturday 27th November 2021.', 'Iberostar Estadi', '8635', '52.9', '47.1', '12', '11', '2', '0', '6', '7', '4', '4', '77', '73.8', '0', '1', '2', '0', '4', '2', '57.1', '54.5', '51.5', '48.5', '0', '2', '8', '19', '19', '8', '3', '0', '0', '0']
# (Total of 36)
#
# Total of 51 links scraped, 137 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/villarreal-vs-barcelona/stats/450648
# ...
# The extracted values:
# ['https://www.skysports.com/football/villarreal-vs-barcelona/stats/450648', '8:00pm, Saturday 27th November 2021.', 'Estadio de la Ceramica', '19050', '50.4', '49.6', '14', '12', '2', '6', '8', '6', '4', '0', '83.5', '80.9', '2', '2', '4', '4', '3', '4', '77.8', '61.5', '50', '50', '3', '1', '19', '14', '13', '19', '2', '2', '0', '0']
# (Total of 36)
#
# Total of 52 links scraped, 136 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/athletic-bilbao-vs-granada/stats/450640
# ...
# The extracted values:
# ['https://www.skysports.com/football/athletic-bilbao-vs-granada/stats/450640', '8:00pm, Friday 26th November 2021.', 'San Mames', '32651', '62.9', '37.1', '17', '8', '5', '4', '5', '2', '7', '2', '83.2', '65.2', '2', '0', '8', '3', '5', '3', '36.4', '69.7', '48.4', '51.6', '1', '3', '12', '9', '8', '12', '1', '2', '1', '0']
# (Total of 36)
#
# Total of 53 links scraped, 135 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/rayo-vallecano-vs-real-mallorca/stats/450636
# ...
# The extracted values:
# ['https://www.skysports.com/football/rayo-vallecano-vs-real-mallorca/stats/450636', '8:00pm, Monday 22nd November 2021.', 'Campo de Futbol de Vallecas', '6708', '52.6', '47.4', '15', '11', '6', '5', '5', '4', '4', '2', '75.4', '74.5', '4', '2', '6', '4', '2', '1', '52.2', '34.8', '59.5', '40.5', '4', '2', '14', '17', '16', '14', '3', '2', '0', '0']
# (Total of 36)
#
# Total of 54 links scraped, 134 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/getafe-vs-cadiz/stats/450633
# ...
# The extracted values:
# ['https://www.skysports.com/football/getafe-vs-cadiz/stats/450633', '1:00pm, Sunday 21st November 2021.', 'Coliseum Alfonso Perez', '8825', '46.9', '53.1', '17', '10', '8', '2', '7', '5', '2', '3', '78.1', '79.5', '2', '0', '3', '7', '0', '0', '62.5', '81.8', '70', '30', '2', '5', '14', '7', '7', '13', '2', '4', '0', '0']
# (Total of 36)
#
# Total of 55 links scraped, 133 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/granada-vs-real-madrid/stats/450634
# ...
# The extracted values:
# ['https://www.skysports.com/football/granada-vs-real-madrid/stats/450634', '3:15pm, Sunday 21st November 2021.', 'Estadio Los Carmenes', '17460', '31.7', '68.3', '11', '21', '3', '10', '4', '7', '4', '4', '79.1', '91.1', '0', '5', '9', '6', '2', '3', '63.2', '45.5', '40', '60', '5', '3', '10', '7', '7', '10', '1', '1', '1', '0']
# (Total of 36)
#
# Total of 56 links scraped, 132 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/elche-vs-real-betis/stats/450632
# ...
# The extracted values:
# ['https://www.skysports.com/football/elche-vs-real-betis/stats/450632', '5:30pm, Sunday 21st November 2021.', 'Martinez Valero', '16127', '57.6', '42.4', '14', '9', '4', '4', '7', '5', '3', '0', '88', '80.9', '1', '2', '10', '1', '1', '2', '61.5', '46.2', '42.1', '57.9', '1', '4', '12', '14', '13', '11', '1', '1', '0', '1']
# (Total of 36)
#
# Total of 57 links scraped, 131 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-sociedad-vs-valencia/stats/450637
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-sociedad-vs
links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-mallorca-vs-elche/stats/450623
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-mallorca-vs-elche/stats/450623', '5:30pm, Sunday 7th November 2021.', 'Iberostar Estadi', '12933', '51.5', '48.5', '18', '7', '6', '2', '3', '2', '9', '3', '81.6', '75.6', '3', '1', '3', '3', '6', '0', '41.7', '52.9', '40.9', '59.1', '0', '4', '11', '19', '19', '10', '2', '3', '0', '0']
# (Total of 36)
#
# Total of 67 links scraped, 121 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-betis-vs-sevilla/stats/450625
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-betis-vs-sevilla/stats/450625', '8:00pm, Sunday 7th November 2021.', 'Benito Villamarin', '50534', '25.6', '74.4', '8', '12', '1', '2', '3', '8', '4', '2', '68.6', '91', '0', '1', '2', '1', '1', '4', '53.8', '41.7', '40', '60', '1', '1', '12', '13', '12', '12', '1', '1', '1', '0']
# (Total of 36)
#
# Total of 68 links scraped, 120 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/espanyol-vs-granada/stats/450622
# ...
# The extracted values:
# ['https://www.skysports.com/football/espanyol-vs-granada/stats/450622', '1:00pm, Saturday 6th November 2021.', 'Cornella - El Prat', '19050', '43.1', '56.9', '17', '18', '6', '5', '8', '9', '3', '4', '83.8', '85.7', '4', '3', '5', '3', '3', '2', '41.7', '71.4', '28.6', '71.4', '5', '4', '12', '8', '8', '11', '1', '1', '0', '0']
# (Total of 36)
#
# Total of 69 links scraped, 119 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/celta-vigo-vs-barcelona/stats/450621
# ...
# The extracted values:
# ['https://www.skysports.com/football/celta-vigo-vs-barcelona/stats/450621', '3:15pm, Saturday 6th November 2021.', 'Balaidos', '13146', '52.4', '47.6', '18', '10', '4', '6', '11', '4', '3', '0', '83.5', '85.9', '2', '1', '3', '1', '2', '2', '66.7', '35.7', '54.5', '45.5', '3', '1', '18', '18', '16', '16', '3', '6', '0', '0']
# (Total of 36)
#
# Total of 70 links scraped, 118 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/alaves-vs-levante/stats/450619
# ...
# The extracted values:
# ['https://www.skysports.com/football/alaves-vs-levante/stats/450619', '5:30pm, Saturday 6th November 2021.', 'Mendizorroza', '12176', '60.5', '39.5', '10', '12', '3', '7', '5', '4', '2', '1', '77.3', '68.3', '1', '1', '1', '3', '2', '2', '66.7', '58.3', '61.8', '38.2', '6', '1', '21', '17', '16', '19', '3', '3', '0', '0']
# (Total of 36)
#
# Total of 71 links scraped, 117 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-madrid-vs-rayo-vallecano/stats/450626
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-madrid-vs-rayo-vallecano/stats/450626', '8:00pm, Saturday 6th November 2021.', 'Santiago Bernabeu', '43283', '54.6', '45.4', '15', '19', '7', '7', '6', '7', '2', '5', '88.6', '89.2', '3', '1', '4', '5', '4', '0', '70', '47.1', '40', '60', '5', '5', '8', '14', '12', '8', '1', '2', '0', '0']
# (Total of 36)
#
# Total of 72 links scraped, 116 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/athletic-bilbao-vs-cadiz/stats/450620
# ...
# The extracted values:
# ['https://www.skysports.com/football/athletic-bilbao-vs-cadiz/stats/450620', '8:00pm, Friday 5th November 2021.', 'San Mames', '37581', '70.3', '29.7', '15', '8', '5', '4', '6', '1', '4', '3', '80.7', '55.4', '0', '0', '5', '1', '1', '0', '30', '59.3', '38.5', '61.5', '3', '4', '14', '19', '17', '14', '3', '1', '0', '0']
# (Total of 36)
#
# Total of 73 links scraped, 115 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/rayo-vallecano-vs-celta-vigo/stats/450615
# ...
# The extracted values:
# ['https://www.skysports.com/football/rayo-vallecano-vs-celta-vigo/stats/450615', '5:30pm, Monday 1st November 2021.', 'Campo de Futbol de Vallecas', '9580', '53', '47', '11', '10', '5', '4', '5', '3', '1', '3', '71.5', '66.8', '0', '0', '4', '7', '3', '3', '90.9', '78.6', '44.2', '55.8', '4', '5', '13', '14', '12', '13', '2', '5', '0', '0']
# (Total of 36)
#
# Total of 74 links scraped, 114 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/levante-vs-granada/stats/450614
# ...
# The extracted values:
# ['https://www.skysports.com/football/levante-vs-granada/stats/450614', '8:00pm, Monday 1st November 2021.', 'Ciutat de Valencia', '14512', '47.7', '52.3', '12', '12', '3', '6', '6', '3', '3', '3', '78.4', '78.3', '1', '1', '3', '5', '3', '1', '33.3', '46.7', '62.5', '37.5', '3', '3', '14', '13', '13', '13', '4', '2', '0', '0']
# (Total of 36)
#
# Total of 75 links scraped, 113 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/cadiz-vs-real-mallorca/stats/450611
# ...
# The extracted values:
# ['https://www.skysports.com/football/cadiz-vs-real-mallorca/stats/450611', '1:00pm, Sunday 31st October 2021.', 'Ramon de Carranza', '11790', '43.5', '56.5', '13', '11', '2', '5', '6', '6', '5', '0', '72', '77.4', '0', '1', '6', '5', '4', '2', '59.1', '70.4', '54.5', '45.5', '4', '1', '14', '16', '15', '13', '3', '5', '0', '1']
# (Total of 36)
#
# Total of 76 links scraped, 112 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/atletico-madrid-vs-real-betis/stats/450609
# ...
# The extracted values:
# ['https://www.skysports.com/football/atletico-madrid-vs-real-betis/stats/450609', '3:15pm, Sunday 31st October 2021.', 'Wanda Metropolitano', '56838', '46.8', '53.2', '18', '8', '9', '1', '7', '3', '2', '4', '82.7', '83.2', '7', '1', '13', '0', '3', '1', '52.9', '53.3', '71.4', '28.6', '1', '7', '11', '12', '12', '11', '0', '0', '0', '0']
# (Total of 36)
#
# Total of 77 links scraped, 111 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/getafe-vs-espanyol/stats/450613
# ...
# The extracted values:
# ['https://www.skysports.com/football/getafe-vs-espanyol/stats/450613', '5:30pm, Sunday 31st October 2021.', 'Coliseum Alfonso Perez', '4721', '43.9', '56.1', '12', '10', '7', '3', '4', '4', '1', '3', '75.6', '78.1', '0', '1', '6', '11', '1', '2', '57.1', '75', '61.1', '38.9', '2', '5', '18', '12', '11', '18', '7', '4', '0', '0']
# (Total of 36)
#
# Total of 78 links scraped, 110 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-sociedad-vs-athletic-bilbao/stats/450616
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-sociedad-vs-athletic-bilbao/stats/450616', '8:00pm, Sunday 31st October 2021.', 'Reale Seguros Stadium', '37066', '54.2', '45.8', '8', '11', '3', '5', '4', '0', '1', '6', '85.1', '78.4', '0', '1', '2', '7', '4', '4', '64.3', '71.4', '57.1', '42.9', '4', '2', '21', '14', '14', '18', '4', '1', '0', '1']
# (Total of 36)
#
# Total of 79 links scraped, 109 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/elche-vs-real-madrid/stats/450612
# ...
# The extracted values:
# ['https://www.skysports.com/football/elche-vs-real-madrid/stats/450612', '1:00pm, Saturday 30th October 2021.', 'Martinez Valero', '23010', '43.7', '56.3', '13', '17', '4', '5', '5', '7', '4', '5', '87.9', '90.2', '2', '3', '5', '4', '1', '1', '57.1', '37.5', '35.7', '64.3', '3', '3', '11', '13', '12', '10', '0', '0', '1', '0']
# (Total of 36)
#
# Total of 80 links scraped, 108 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/sevilla-vs-osasuna/stats/450617
# ...
# The extracted values:
# ['https://www.skysports.com/football/sevilla-vs-osasuna/stats/450617', '3:15pm, Saturday 30th October 2021.', 'Ramon Sanchez Pizjuan', '20335', '64.2', '35.8', '16', '10', '4', '3', '5', '4', '7', '3', '81.7', '62.1', '4', '1', '4', '5', '5', '3', '71.4', '71.4', '54.5', '45.5', '3', '2', '17', '10', '10', '17', '2', '2', '0', '0']
# (Total of 36)
#
# Total of 81 links scraped, 107 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/valencia-vs-villarreal/stats/450618
# ...
# The extracted values:
# ['https://www.skysports.com/football/valencia-vs-villarreal/stats/450618', '5:30pm, Saturday 30th October 2021.', 'Mestalla', '31487', '25', '75', '9', '11', '3', '1', '5', '6', '1', '4', '57.4', '85.3', '2', '1', '7', '6', '4', '2', '73.7', '72.7', '37.1', '62.9', '1', '0', '19', '17', '17', '18', '2', '4', '0', '0']
# (Total of 36)
#
# Total of 82 links scraped, 106 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/barcelona-vs-alaves/stats/450610
# ...
# The extracted values:
# ['https://www.skysports.com/football/barcelona-vs-alaves/stats/450610', '8:00pm, Saturday 30th October 2021.', 'Camp Nou', '37278', '79.4', '20.6', '16', '3', '5', '2', '8', '1', '3', '0', '90.9', '64.2', '3', '1', '9', '0', '1', '2', '71.4', '52.9', '46.2', '53.8', '1', '4', '11', '11', '11', '8', '0', '2', '0', '0']
# (Total of 36)
#
# Total of 83 links scraped, 105 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/celta-vigo-vs-real-sociedad/stats/450600
# ...
# The extracted values:
# ['https://www.skysports.com/football/celta-vigo-vs-real-sociedad/stats/450600', '6:00pm, Thursday 28th October 2021.', 'Balaidos', '8726', '57', '43', '14', '11', '6', '4', '5', '3', '3', '4', '82.5', '75.4', '1', '0', '7', '6', '3', '0', '39.1', '63.2', '39.5', '60.5', '2', '6', '12', '11', '10', '11', '1', '0', '0', '0']
# (Total of 36)
#
# Total of 84 links scraped, 104 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/granada-vs-getafe/stats/450602
# ...
# The extracted values:
# ['https://www.skysports.com/football/granada-vs-getafe/stats/450602', '7:00pm, Thursday 28th October 2021.', 'Estadio Los Carmenes', '13651', '76.6', '23.4', '18', '6', '3', '4', '11', '2', '4', '0', '83.1', '59', '1', '1', '5', '0', '3', '2', '70.6', '58.3', '41.5', '58.5', '3', '2', '10', '15', '12', '10', '1', '4', '0', '0']
# (Total of 36)
#
# Total of 85 links scraped, 103 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/levante-vs-atletico-madrid/stats/450603
# ...
# The extracted values:
# ['https://www.skysports.com/football/levante-vs-atletico-madrid/stats/450603', '8:30pm, Thursday 28th October 2021.', 'Ciutat de Valencia', '16298', '34.9', '65.1', '10', '7', '3', '3', '4', '3', '3', '1', '77', '86.3', '1', '1', '5', '2', '4', '4', '75', '71.4', '27.3', '72.7', '1', '1', '15', '11', '8', '15', '1', '5', '1', '0']
# (Total of 36)
#
# Total of 86 links scraped, 102 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/rayo-vallecano-vs-barcelona/stats/450605
# ...
# The extracted values:
# ['https://www.skysports.com/football/rayo-vallecano-vs-barcelona/stats/450605', '6:00pm, Wednesday 27th October 2021.', 'Campo de Futbol de Vallecas', '9340', '31.3', '68.7', '12', '16', '3', '1', '5', '9', '4', '6', '70.8', '87.7', '0', '4', '3', '7', '5', '1', '54.5', '54.5', '41.7', '58.3', '1', '2', '17', '12', '11', '17', '2', '2', '0', '0']
# (Total of 36)
#
# Total of 87 links scraped, 101 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-mallorca-vs-sevilla/stats/450604
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-mallorca-vs-sevilla/stats/450604', '6:00pm, Wednesday 27th October 2021.', 'Iberostar Estadi', '15125', '30.2', '69.8', '11', '10', '4', '3', '3', '6', '4', '1', '72.5', '88.1', '1', '3', '4', '2', '1', '2', '50', '62.5', '34.5', '65.5', '2', '3', '16', '14', '13', '15', '4', '6', '1', '0']
# (Total of 36)
#
# Total of 88 links scraped, 100 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-betis-vs-valencia/stats/450606
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-betis-vs-valencia/stats/450606', '7:00pm, Wednesday 27th October 2021.', 'Benito Villamarin', '43123', '61.1', '38.9', '14', '10', '9', '4', '2', '5', '3', '1', '77.9', '63.9', '1', '2', '4', '7', '2', '1', '56.3', '35.7', '63.6', '36.4', '3', '5', '14', '19', '18', '13', '2', '5', '0', '0']
# (Total of 36)
#
# Total of 89 links scraped, 99 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-madrid-vs-osasuna/stats/450607
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-madrid-vs-osasuna/stats/450607', '8:30pm, Wednesday 27th October 2021.', 'Santiago Bernabeu', '35691', '74.7', '25.3', '17', '7', '3', '0', '11', '7', '3', '0', '90.2', '67.5', '0', '1', '11', '3', '5', '0', '42.9', '71.4', '44.4', '55.6', '0', '3', '12', '10', '9', '12', '1', '1', '0', '0']
# (Total of 36)
#
# Total of 90 links scraped, 98 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/alaves-vs-elche/stats/450599
# ...
# The extracted values:
# ['https://www.skysports.com/football/alaves-vs-elche/stats/450599', '6:00pm, Tuesday 26th October 2021.', 'Mendizorroza', '10206', '38.3', '61.7', '16', '4', '5', '1', '6', '1', '5', '2', '79.2', '83.8', '3', '0', '4', '7', '2', '2', '52.6', '50', '50', '50', '1', '4', '13', '9', '9', '13', '1', '1', '0', '0']
# (Total of 36)
#
# Total of 91 links scraped, 97 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/espanyol-vs-athletic-bilbao/stats/450601
# ...
# The extracted values:
# ['https://www.skysports.com/football/espanyol-vs-athletic-bilbao/stats/450601', '8:00pm, Tuesday 26th October 2021.', 'Cornella - El Prat', '16196', '45.9', '54.1', '14', '23', '3', '7', '7', '9', '4', '7', '84.4', '86', '0', '4', '8', '12', '0', '2', '36.4', '64.7', '20', '80', '5', '2', '7', '12', '10', '6', '1', '2', '1', '0']
# (Total of 36)
#
# Total of 92 links scraped, 96 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/villarreal-vs-cadiz/stats/450608
# ...
# The extracted values:
# ['https://www.skysports.com/football/villarreal-vs-cadiz/stats/450608', '8:30pm, Tuesday 26th October 2021.', 'Estadio de la Ceramica', '12190', '77.5', '22.5', '14', '9', '5', '4', '5', '4', '4', '1', '86.6', '62.3', '4', '3', '8', '2', '4', '8', '80', '50', '47.8', '52.2', '1', '2', '13', '9', '9', '11', '3', '6', '0', '0']
# (Total of 36)
#
# Total of 93 links scraped, 95 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/getafe-vs-celta-vigo/stats/450594
# ...
# The extracted values:
# ['https://www.skysports.com/football/getafe-vs-celta-vigo/stats/450594', '8:00pm, Monday 25th October 2021.', 'Coliseum Alfonso Perez', '7630', '34.4', '65.6', '11', '16', '2', '8', '6', '6', '3', '2', '74.8', '85.2', '0', '4', '2', '7', '0', '1', '81.8', '35.7', '36.4', '63.6', '5', '2', '15', '11', '11', '15', '2', '2', '2', '0']
# (Total of 36)
#
# Total of 94 links scraped, 94 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/sevilla-vs-levante/stats/450597
# ...
# The extracted values:
# ...
# (Total of 36)
#
# Total of 157 links scraped, 31 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/levante-vs-rayo-vallecano/stats/450534
# ...
# The extracted values:
# ['https://www.skysports.com/football/levante-vs-rayo-vallecano/stats/450534', '5:30pm, Saturday 11th September 2021.', 'Ciutat de Valencia', '12974', '45', '55', '7', '22', '2', '6', '1', '12', '4', '4', '75.5', '80.8', '0', '5', '2', '5', '3', '2', '47.1', '50', '54.8', '45.2', '5', '1', '14', '16', '15', '14', '3', '4', '0', '0']
# (Total of 36)
#
# Total of 158 links scraped, 30 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/athletic-bilbao-vs-real-mallorca/stats/450529
# ...
# The extracted values:
# ['https://www.skysports.com/football/athletic-bilbao-vs-real-mallorca/stats/450529', '8:00pm, Saturday 11th September 2021.', 'San Mames', '14566', '47.9', '52.1', '19', '7', '5', '1', '8', '3', '6', '3', '74.3', '76', '3', '0', '7', '2', '3', '0', '62.5', '61.5', '43.2', '56.8', '1', '4', '7', '13', '13', '7', '1', '2', '0', '0']
# (Total of 36)
#
# Total of 159 links scraped, 29 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/barcelona-vs-getafe/stats/450520
# ...
# The extracted values:
# ['https://www.skysports.com/football/barcelona-vs-getafe/stats/450520', '4:00pm, Sunday 29th August 2021.', 'Camp Nou', '26543', '66.6', '33.4', '7', '8', '3', '3', '2', '5', '2', '0', '86.1', '74.5', '2', '0', '3', '2', '3', '1', '50', '61.1', '28', '72', '2', '1', '16', '22', '19', '15', '3', '1', '0', '0']
# (Total of 36)
#
# Total of 160 links scraped, 28 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/cadiz-vs-osasuna/stats/450522
# ...
# The extracted values:
# ['https://www.skysports.com/football/cadiz-vs-osasuna/stats/450522', '6:30pm, Sunday 29th August 2021.', 'Ramon de Carranza', '7452', '27.1', '72.9', '7', '14', '3', '4', '3', '7', '1', '3', '57.7', '82.4', '1', '2', '4', '11', '0', '1', '76.5', '50', '31.4', '68.6', '1', '1', '9', '6', '5', '6', '4', '0', '0', '0']
# (Total of 36)
#
# Total of 161 links scraped, 27 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/rayo-vallecano-vs-granada/stats/450525
# ...
# The extracted values:
# ['https://www.skysports.com/football/rayo-vallecano-vs-granada/stats/450525', '6:30pm, Sunday 29th August 2021.', 'Campo de Futbol de Vallecas', '583', '46.9', '53.1', '19', '9', '6', '3', '8', '3', '5', '3', '70.9', '71.4', '0', '1', '5', '7', '2', '0', '30.8', '61.5', '62.2', '37.8', '3', '2', '19', '14', '13', '17', '1', '4', '0', '0']
# (Total of 36)
#
# Total of 162 links scraped, 26 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/atletico-madrid-vs-villarreal/stats/450519
# ...
# The extracted values:
# ['https://www.skysports.com/football/atletico-madrid-vs-villarreal/stats/450519', '9:00pm, Sunday 29th August 2021.', 'Wanda Metropolitano', '26840', '48.9', '51.1', '23', '2', '4', '2', '11', '0', '8', '0', '87', '82.6', '1', '1', '16', '0', '5', '1', '66.7', '62.5', '38.1', '61.9', '0', '2', '11', '6', '6', '11', '5', '2', '0', '0']
# (Total of 36)
#
# Total of 163 links scraped, 25 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/celta-vigo-vs-athletic-bilbao/stats/450521
# ...
# The extracted values:
# ['https://www.skysports.com/football/celta-vigo-vs-athletic-bilbao/stats/450521', '4:00pm, Saturday 28th August 2021.', 'Balaidos', '5492', '61.8', '38.2', '13', '6', '0', '2', '9', '2', '4', '2', '75.2', '61.5', '1', '3', '5', '4', '5', '1', '64', '61.5', '56.3', '43.8', '1', '0', '12', '11', '10', '11', '2', '1', '0', '0']
# (Total of 36)
#
# Total of 164 links scraped, 24 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/elche-vs-sevilla/stats/450523
# ...
# The extracted values:
# ['https://www.skysports.com/football/elche-vs-sevilla/stats/450523', '6:30pm, Saturday 28th August 2021.', 'Martinez Valero', '10385', '29.1', '70.9', '7', '18', '4', '5', '3', '10', '0', '3', '66.7', '89.1', '1', '3', '5', '3', '2', '0', '50', '70', '47.4', '52.6', '4', '3', '6', '9', '9', '5', '2', '0', '0', '0']
# (Total of 36)
#
# Total of 165 links scraped, 23 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-sociedad-vs-levante/stats/450527
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-sociedad-vs-levante/stats/450527', '6:30pm, Saturday 28th August 2021.', 'Reale Seguros Stadium', '7758', '51.5', '48.5', '7', '6', '2', '0', '5', '4', '0', '2', '83.8', '81.9', '1', '0', '2', '2', '1', '1', '61.5', '57.1', '73.9', '26.1', '0', '1', '17', '13', '13', '17', '1', '1', '0', '0']
# (Total of 36)
#
# Total of 166 links scraped, 22 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-mallorca-vs-espanyol/stats/450524
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-mallorca-vs-espanyol/stats/450524', '7:00pm, Friday 27th August 2021.', 'Iberostar Estadi', '7529', '47.1', '52.9', '12', '8', '6', '3', '5', '3', '1', '2', '77.6', '79.6', '1', '0', '3', '2', '2', '1', '53.3', '73.7', '63', '37', '3', '5', '16', '17', '16', '15', '4', '3', '0', '1']
# (Total of 36)
#
# Total of 167 links scraped, 21 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/valencia-vs-alaves/stats/450528
# ...
# The extracted values:
# ['https://www.skysports.com/football/valencia-vs-alaves/stats/450528', '9:15pm, Friday 27th August 2021.', 'Mestalla', '10627', '48.8', '51.2', '9', '9', '4', '2', '4', '5', '1', '2', '76.5', '76.1', '3', '0', '4', '4', '2', '2', '57.1', '71.4', '39', '61', '2', '1', '20', '15', '15', '19', '1', '4', '0', '0']
# (Total of 36)
#
# Total of 168 links scraped, 20 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/getafe-vs-sevilla/stats/450513
# ...
# The extracted values:
# ['https://www.skysports.com/football/getafe-vs-sevilla/stats/450513', '7:00pm, Monday 23rd August 2021.', 'Coliseum Alfonso Perez', '4810', '38.6', '61.4', '12', '9', '0', '3', '7', '5', '5', '1', '72.4', '84.6', '0', '1', '5', '4', '1', '3', '75', '33.3', '65', '35', '2', '0', '18', '10', '10', '17', '3', '2', '0', '0']
# (Total of 36)
#
# Total of 169 links scraped, 19 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/osasuna-vs-celta-vigo/stats/450516
# ...
# The extracted values:
# ['https://www.skysports.com/football/osasuna-vs-celta-vigo/stats/450516', '9:00pm, Monday 23rd August 2021.', 'El Sadar', '7189', '46.3', '53.7', '15', '4', '7', '0', '7', '4', '1', '0', '71.4', '75.6', '4', '0', '1', '2', '0', '2', '68.4', '76.9', '63', '37', '0', '7', '19', '8', '8', '19', '4', '3', '0', '0']
# (Total of 36)
#
# Total of 170 links scraped, 18 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-sociedad-vs-rayo-vallecano/stats/450518
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-sociedad-vs-rayo-vallecano/stats/450518', '4:00pm, Sunday 22nd August 2021.', 'Reale Seguros Stadium', '7652', '61.2', '38.8', '13', '9', '8', '1', '2', '7', '3', '1', '84.2', '75.7', '1', '1', '5', '4', '0', '2', '40', '42.1', '51.4', '48.6', '1', '7', '19', '15', '14', '18', '3', '4', '0', '0']
# (Total of 36)
#
# Total of 171 links scraped, 17 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/atletico-madrid-vs-elche/stats/450511
# ...
# The extracted values:
# ['https://www.skysports.com/football/atletico-madrid-vs-elche/stats/450511', '6:30pm, Sunday 22nd August 2021.', 'Wanda Metropolitano', '24926', '41.8', '58.2', '8', '4', '4', '2', '4', '2', '0', '0', '84.3', '88.3', '1', '0', '2', '1', '5', '0', '59.3', '58.3', '53.8', '46.2', '2', '3', '16', '10', '9', '16', '2', '2', '0', '0']
# (Total of 36)
#
# Total of 172 links scraped, 16 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/levante-vs-real-madrid/stats/450515
# ...
# The extracted values:
# ['https://www.skysports.com/football/levante-vs-real-madrid/stats/450515', '9:00pm, Sunday 22nd August 2021.', 'Ciutat de Valencia', '9838', '38.6', '61.4', '8', '20', '4', '5', '3', '7', '1', '8', '80.6', '89.6', '2', '3', '4', '6', '0', '5', '50', '52.9', '45.5', '54.5', '2', '1', '17', '7', '6', '15', '3', '2', '1', '0']
# (Total of 36)
#
# Total of 173 links scraped, 15 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/alaves-vs-real-mallorca/stats/450509
# ...
# The extracted values:
# ['https://www.skysports.com/football/alaves-vs-real-mallorca/stats/450509', '4:00pm, Saturday 21st August 2021.', 'Mendizorroza', '2896', '47.3', '52.7', '9', '12', '4', '2', '5', '8', '0', '2', '74', '78.8', '1', '2', '1', '8', '0', '2', '70.8', '62.5', '35.5', '64.5', '1', '4', '14', '15', '14', '13', '1', '3', '1', '0']
# (Total of 36)
#
# Total of 174 links scraped, 14 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/espanyol-vs-villarreal/stats/450512
# ...
# The extracted values:
# ['https://www.skysports.com/football/espanyol-vs-villarreal/stats/450512', '6:30pm, Saturday 21st August 2021.', 'Cornella - El Prat', '11095', '40.4', '59.6', '14', '12', '3', '2', '8', '5', '3', '5', '79.1', '88', '1', '0', '9', '7', '3', '3', '58.3', '50', '39.1', '60.9', '2', '3', '10', '10', '8', '9', '3', '4', '0', '0']
# (Total of 36)
#
# Total of 175 links scraped, 13 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/granada-vs-valencia/stats/450514
# ...
# The extracted values:
# ['https://www.skysports.com/football/granada-vs-valencia/stats/450514', '6:30pm, Saturday 21st August 2021.', 'Estadio Los Carmenes', '6267', '46.3', '53.7', '9', '18', '2', '7', '6', '10', '1', '1', '58.7', '69', '1', '0', '2', '6', '3', '3', '55.6', '62.5', '50', '50', '5', '1', '14', '12', '11', '14', '4', '2', '0', '0']
# (Total of 36)
#
# Total of 176 links scraped, 12 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/athletic-bilbao-vs-barcelona/stats/450510
# ...
# The extracted values:
# ['https://www.skysports.com/football/athletic-bilbao-vs-barcelona/stats/450510', '9:00pm, Saturday 21st August 2021.', 'San Mames', '9394', '32.8', '67.2', '16', '9', '7', '3', '4', '5', '5', '1', '73.2', '87.3', '0', '1', '13', '2', '3', '2', '33.3', '46.2', '57.7', '42.3', '2', '5', '15', '10', '9', '13', '1', '2', '0', '1']
# (Total of 36)
#
# Total of 177 links scraped, 11 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-betis-vs-cadiz/stats/450517
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-betis-vs-cadiz/stats/450517', '8:00pm, Friday 20th August 2021.', 'Benito Villamarin', '23745', '74.3', '25.7', '16', '8', '7', '3', '7', '3', '2', '2', '89.7', '61.5', '2', '1', '4', '5', '0', '0', '100', '43.5', '47.1', '52.9', '2', '6', '12', '10', '8', '11', '4', '0', '0', '0']
# (Total of 36)
#
# Total of 178 links scraped, 10 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/villarreal-vs-granada/stats/450508
# ...
# The extracted values:
# ['https://www.skysports.com/football/villarreal-vs-granada/stats/450508', '7:00pm, Monday 16th August 2021.', 'Estadio de la Ceramica', '7837', '60.5', '39.5', '14', '6', '4', '1', '8', '4', '2', '1', '82.8', '75.2', '2', '0', '6', '2', '1', '0', '57.9', '62.5', '65.6', '34.4', '1', '3', '19', '21', '18', '17', '2', '1', '1', '0']
# (Total of 36)
#
# Total of 179 links scraped, 9 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/elche-vs-athletic-bilbao/stats/450503
# ...
# The extracted values:
# ['https://www.skysports.com/football/elche-vs-athletic-bilbao/stats/450503', '9:00pm, Monday 16th August 2021.', 'Martinez Valero', '9145', '50.2', '49.8', '8', '9', '2', '3', '6', '5', '0', '1', '80.2', '78.8', '1', '1', '6', '8', '5', '1', '71.4', '55.6', '40.7', '59.3', '3', '2', '13', '19', '18', '13', '2', '2', '0', '0']
# (Total of 36)
#
# Total of 180 links scraped, 8 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/celta-vigo-vs-atletico-madrid/stats/450501
# ...
# The extracted values:
# ['https://www.skysports.com/football/celta-vigo-vs-atletico-madrid/stats/450501', '4:30pm, Sunday 15th August 2021.', 'Balaidos', '5401', '53.2', '46.8', '10', '13', '2', '5', '3', '3', '5', '5', '83.5', '80.2', '1', '1', '2', '5', '1', '1', '52.6', '41.7', '20', '80', '2', '1', '11', '9', '8', '11', '3', '5', '1', '1']
# (Total of 36)
#
# Total of 181 links scraped, 7 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/barcelona-vs-real-sociedad/stats/450500
# ...
# The extracted values:
# ['https://www.skysports.com/football/barcelona-vs-real-sociedad/stats/450500', '7:00pm, Sunday 15th August 2021.', 'Camp Nou', '20384', '61.7', '38.3', '13', '11', '8', '3', '4', '5', '1', '3', '88.3', '78.2', '5', '1', '5', '3', '1', '2', '40', '59.1', '45.8', '54.2', '1', '4', '11', '18', '17', '11', '2', '4', '0', '0']
# (Total of 36)
#
# Total of 182 links scraped, 6 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/sevilla-vs-rayo-vallecano/stats/450506
# ...
# The extracted values:
# ['https://www.skysports.com/football/sevilla-vs-rayo-vallecano/stats/450506', '9:15pm, Sunday 15th August 2021.', 'Ramon Sanchez Pizjuan', '13962', '75.3', '24.7', '21', '4', '8', '3', '7', '0', '6', '1', '93.1', '69.4', '4', '1', '4', '0', '1', '1', '60', '70', '39.1', '60.9', '3', '5', '14', '7', '7', '14', '1', '0', '0', '1']
# (Total of 36)
#
# Total of 183 links scraped, 5 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/cadiz-vs-levante/stats/450502
# ...
# The extracted values:
# ['https://www.skysports.com/football/cadiz-vs-levante/stats/450502', '6:30pm, Saturday 14th August 2021.', 'Ramon de Carranza', '6941', '43.1', '56.9', '7', '12', '2', '3', '3', '8', '2', '1', '72.4', '83.8', '1', '0', '2', '4', '1', '1', '57.1', '72.7', '60.6', '39.4', '2', '1', '10', '16', '15', '9', '1', '5', '0', '0']
# (Total of 36)
#
# Total of 184 links scraped, 4 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/real-mallorca-vs-real-betis/stats/450504
# ...
# The extracted values:
# ['https://www.skysports.com/football/real-mallorca-vs-real-betis/stats/450504', '6:30pm, Saturday 14th August 2021.', 'Iberostar Estadi', '6279', '34.2', '65.8', '6', '10', '2', '1', '4', '7', '0', '2', '77.8', '88.6', '1', '1', '4', '3', '3', '0', '52.9', '63.6', '50', '50', '0', '1', '12', '18', '18', '12', '1', '3', '0', '0']
# (Total of 36)
#
# Total of 185 links scraped, 3 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/alaves-vs-real-madrid/stats/450499
# ...
# The extracted values:
# ['https://www.skysports.com/football/alaves-vs-real-madrid/stats/450499', '9:00pm, Saturday 14th August 2021.', 'Mendizorroza', '3968', '40.7', '59.3', '11', '19', '4', '7', '3', '8', '4', '4', '83.8', '88.7', '0', '3', '0', '4', '1', '2', '50', '50', '80', '20', '4', '3', '14', '10', '9', '14', '1', '2', '0', '0']
# (Total of 36)
#
# Total of 186 links scraped, 2 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/osasuna-vs-espanyol/stats/450505
# ...
# The extracted values:
# ['https://www.skysports.com/football/osasuna-vs-espanyol/stats/450505', '9:00pm, Saturday 14th August 2021.', 'El Sadar', '6715', '52.9', '47.1', '14', '10', '1', '3', '8', '5', '5', '2', '75', '71', '0', '1', '4', '6', '1', '3', '60', '63.2', '56.1', '43.9', '3', '1', '18', '12', '11', '18', '3', '3', '0', '0']
# (Total of 36)
#
# Total of 187 links scraped, 1 links remaining.
#
# Adding the link:
# https://www.skysports.com/football/valencia-vs-getafe/stats/450507
# ...
# The extracted values:
# ['https://www.skysports.com/football/valencia-vs-getafe/stats/450507', '8:00pm, Friday 13th August 2021.', 'Mestalla', '9868', '26.4', '73.6', '4', '22', '2', '4', '2', '12', '0', '6', '64.4', '86.7', '1', '0', '1', '9', '2', '2', '71.4', '80', '72.4', '27.6', '4', '1', '24', '15', '15', '24', '6', '2', '1', '1']
# (Total of 36)
#
# Total of 188 links scraped, 0 links remaining.
