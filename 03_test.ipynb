# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reloading the saved model

# %%
import joblib

# For prediction using a SK-Learn model load 'trained_model_sklearn.joblib'
pipeline = joblib.load("./trained_models/model_panel_data.joblib")

# %% [markdown]
# # Loading the test data

# %%
import pandas as pd

df = pd.read_csv("./dataset/04_test.csv")

df
# Out:
#            date     season  fulltime_result  is_home             team  \
# 0    2022-08-26  2022_2023                2        0       Celta Vigo
# 1    2022-08-26  2022_2023                0        0          Osasuna
# 2    2022-08-27  2022_2023                2        0    Real Sociedad
# 3    2022-08-27  2022_2023                2        0    Real Mallorca
# 4    2022-08-27  2022_2023                0        0          Sevilla
# ..          ...        ...              ...      ...              ...
# 411  2023-02-26  2022_2023                0        1  Athletic Bilbao
# 412  2023-02-26  2022_2023                2        1       Celta Vigo
# 413  2023-02-26  2022_2023                2        1          Almeria
# 414  2023-02-26  2022_2023                0        1          Sevilla
# 415  2023-02-27  2022_2023                2        1       Villarreal
#
#      team_fulltime_goals  team_win_bet365_probs  team_pre_rating  \
# 0                      1                   0.32             1949
# 1                      2                   0.47             1942
# 2                      1                   0.24             2023
# 3                      1                   0.43             1862
# 4                      1                   0.24             2084
# ..                   ...                    ...              ...
# 411                    0                   0.16             2045
# 412                    1                   0.16             1928
# 413                    2                   0.53             1860
# 414                    1                   0.19             2008
# 415                    0                   0.15             2035
#
#      team_possession  team_total_shots  ...  fd_team_shots_off_target  \
# 0                 50                15  ...                         5
# 1                 55                16  ...                         5
# 2                 41                10  ...                         0
# 3                 47                13  ...                         1
# 4                 61                18  ...                         7
# ..               ...               ...  ...                       ...
# 411               43                 8  ...                        -5
# 412               44                18  ...                         0
# 413               48                16  ...                         3
# 414               41                 7  ...                        -2
# 415               53                11  ...                         3
#
#      fd_team_clear_cut_chances  fd_team_xg  fd_opponent_fulltime_goals  \
# 0                            0         1.0                           3
# 1                            1         1.2                          -1
# 2                           -3        -0.7                           1
# 3                            3         0.2                           2
# 4                            1         1.1                           0
# ..                         ...         ...                         ...
# 411                          0        -0.5                           6
# 412                          0         0.3                           1
# 413                          0        -0.5                           1
# 414                          0        -1.6                           0
# 415                         -2        -0.3                           0
#
#      fd_opponent_win_bet365_probs  fd_opponent_total_shots  \
# 0                           -0.13                        7
# 1                            0.17                       -9
# 2                           -0.25                        9
# 3                           -0.23                        4
# 4                           -0.20                        2
# ..                            ...                      ...
# 411                         -0.10                        7
# 412                          0.23                       -1
# 413                         -0.13                       10
# 414                          0.13                       -4
# 415                         -0.01                        2
#
#      fd_opponent_shots_on_target  fd_opponent_shots_off_target  \
# 0                              5                             3
# 1                             -5                            -1
# 2                              1                             4
# 3                              1                             2
# 4                              1                            -2
# ..                           ...                           ...
# 411                            7                             1
# 412                           -2                             0
# 413                            1                             7
# 414                            0                            -2
# 415                            2                            -1
#
#      fd_opponent_clear_cut_chances  fd_opponent_xg
# 0                                2             1.0
# 1                               -2            -1.0
# 2                                1             0.6
# 3                                2             0.9
# 4                                0             0.0
# ..                             ...             ...
# 411                              6             2.7
# 412                             -2            -0.6
# 413                              0             0.6
# 414                             -1            -0.2
# 415                              3             0.2
#
# [416 rows x 43 columns]

# %% [markdown]
# # Spliting the dataset

# %%
# Removing the unnecessary columns other than first differance and a selected set of ordinaries
cols_to_remove = [col for col in df.columns if (
    ((col[:5] == 'team_') or (col[:9] == 'opponent_')) and
    ('rating' not in col) and
    ('xg' not in col) and
    ('probs' not in col))] + ['season', 'date', 'team']
df = df.drop(cols_to_remove, axis='columns')

# Setting the independent variables and the target class
X = df.drop(['fulltime_result'], axis='columns')
y = df['fulltime_result']

# %% [markdown]
# # Testing the model

# %% [markdown]
# The code below receives a model and a set of X data and predicts the target variable; then compares the target variable with the given actual y and returns the accuracy and the confusion matrix.

# %%
import sklearn.metrics as metrics

def test_model(model, X, y):
    probs = pipeline.predict(X)

    accuracy_score = metrics.accuracy_score(y, probs)

    print("The accuracy score using the test set is %.2f%%" %(accuracy_score*100))

    metrics.ConfusionMatrixDisplay.from_predictions(
        y_true=y,
        y_pred=probs,
        display_labels=['Lose', 'Draw', 'Win']);

    metrics.ConfusionMatrixDisplay.from_predictions(
        y_true=y,
        y_pred=probs,
        display_labels=['Lose', 'Draw', 'Win'],
        normalize='true');
    
    return probs

# %%
test_model(pipeline, X, y);
# Out:
# The accuracy score using the test set is 55.77%
